# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## COLOQUE AQUI SEU NOME
# Raphael Azevedo
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!
#
# Nesse projeto viso analisar o uso de internet em domícilios, em relação ao uso de tv(Quem tem internet em casa X Quem tem assinatura de tv) quando análisando domicílios de média-baixa renda. Pretendo ver qual das duas mídias se tornou "mais popular" em termos de uso nos últimos anos.

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Raphael\Documents\Python Notebooks

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')
dados = pd.read_csv('DOM2015.csv',sep=',')
#dados.TVASS = dados.V02272.astype('category')
#dados['Tv por assinatura' == dados.V02272]
#dadosN = pd.DataFrame({'TV por assinatura':dados.V02272,'Tem internet em casa':dados.V02322,'Unidade Federal':dados.UF,'Faixa do rendimento mensal':dados.V4622,'Tem microcomputador':dados.V0231,'Tem televisão em cores':dados.V0226,'Tem televisão em preto e branco':dados.V0227})
#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')
dados.V02322 = dados.V02322.astype('category')
dados.V02272 = dados.V02272.astype('category')
dados.UF = dados.UF.astype('category')
dados.V4622 = dados.V4622.astype('category')
dados.V0231 = dados.V0231.astype('category')
dados.V0226 = dados.V0226.astype('category')
dados.V0227 = dados.V0227.astype('category')
dados.V02322.cat.categories = ('Sim','Não')
dados.V02272.cat.categories = ('Sim','Não')
dados.UF.cat.categories = ('Rondônia','Acre','Amazonas','Roraima','Pará','Amapá','Tocantins','Maranhão','Piauí','Ceará','Rio Grande do Norte','Paraíba','Pernambuco','Alagoas','Sergipe','Bahia','Minas Gerais','Espírito Santo','Rio de Janeiro','São Paulo','Paraná','Santa Catarina','Rio Grande do Sul','Mato Grosso do Sul','Mato Grosso','Goiás','Distrito Federal')
dados.V4622.cat.categories = ('Sem Redimento','Até 1/4 salário mínimo','Mais de 1/4 até 1/2 de salário mínimo','Mais de 1/2 até 1 salário mínimo','Mais de 1 até 2 salários mínimos','Mais de 2 até 3 salários mínimos','Mais de 3 até 5 salários mínimos','Mais de 5 salários mínimos','Sem declaração')
dados.V0231.cat.categories = ('Sim','Não')
dados.V0226.cat.categories = ('Sim','Não')
dados.V0227.cat.categories = ('Sim','Não')
dadosN = pd.DataFrame({'TV por assinatura':dados.V02272,'Tem internet em casa':dados.V02322,'Unidade Federal':dados.UF,'Faixa do rendimento mensal':dados.V4622,'Tem microcomputador':dados.V0231,'Tem televisão em cores':dados.V0226,'Tem televisão em preto e branco':dados.V0227})

dadosN.dropna(how='any')
#df1.dropna(how='any')
# Out:
#                    Faixa do rendimento mensal TV por assinatura  \
# 75           Mais de 1 até 2 salários mínimos               Não
# 1723                   Até 1/4 salário mínimo               Não
# 2100         Mais de 1/2 até 1 salário mínimo               Não
# 3013                   Até 1/4 salário mínimo               Não
# 3879         Mais de 1/2 até 1 salário mínimo               Não
# 4968         Mais de 2 até 3 salários mínimos               Não
# 5211    Mais de 1/4 até 1/2 de salário mínimo               Não
# 6137         Mais de 1/2 até 1 salário mínimo               Não
# 6198    Mais de 1/4 até 1/2 de salário mínimo               Não
# 7310         Mais de 1/2 até 1 salário mínimo               Não
# 7422    Mais de 1/4 até 1/2 de salário mínimo               Não
# 7570         Mais de 2 até 3 salários mínimos               Não
# 7774    Mais de 1/4 até 1/2 de salário mínimo               Não
# 9430         Mais de 1 até 2 salários mínimos               Não
# ...

# %%
dadosN
# Out:
#                    Faixa do rendimento mensal TV por assinatura  \
# 0            Mais de 1 até 2 salários mínimos               Não
# 1                                         NaN               NaN
# 2            Mais de 1 até 2 salários mínimos               NaN
# 3            Mais de 1 até 2 salários mínimos               Não
# 4            Mais de 3 até 5 salários mínimos               NaN
# 5            Mais de 2 até 3 salários mínimos               Não
# 6       Mais de 1/4 até 1/2 de salário mínimo               Não
# 7            Mais de 1 até 2 salários mínimos               Não
# 8            Mais de 1 até 2 salários mínimos               Não
# 9                                         NaN               NaN
# 10           Mais de 2 até 3 salários mínimos               Sim
# 11           Mais de 3 até 5 salários mínimos               Não
# 12                                        NaN               NaN
# 13           Mais de 1 até 2 salários mínimos               Não
# ...

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
